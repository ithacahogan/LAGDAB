# %% [markdown]
# <a href="https://colab.research.google.com/github/ithacahogan/LAGDAB/blob/main/20250910_DataAnalyticsInPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaGuardiaDataAnalytics/datasets/master/faithful.csv', index_col=0)

# %%
df.head() #will show first 5 rows of the cvs from the dataframe
# Out:
#    eruptions  waiting
# 1      3.600       79
# 2      1.800       54
# 3      3.333       74
# 4      2.283       62
# 5      4.533       85

# %%
df.tail() #will show the last 5 or (n) numbers of rows from dataframe
# Out:
#      eruptions  waiting
# 268      4.117       81
# 269      2.150       46
# 270      4.417       90
# 271      1.817       46
# 272      4.467       74
