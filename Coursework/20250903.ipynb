# %% [markdown]
# <a href="https://colab.research.google.com/github/ithacahogan/LAGDAB/blob/main/20250903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#starting a dictionary
patient_2 = {}
patient_2 ['first_name'] = 'John'
patient_2 ['last_name'] = 'Picard'
print(patient_2)
# Out:
# {'first_name': 'John', 'last_name': 'Picard'}

# %%
#now it has turned into a dictionary
#modifying values
del patient_2 ['first_name']
print(patient_2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2012477289.py in <cell line: 0>()
#       1 #now it has turned into a dictionary
#       2 #modifying values
# ----> 3 del patient_2 ['first_name']
#       4 print(patient_2)
#
# KeyError: 'first_name'

# %%
print(patient_2)
# Out:
# {'last_name': 'Picard'}

# %%
#dictionairies can store lots of info
patient_3 ={
    'name': 'Jack',
    'last_name' : 'Jillianson',
    'mrn' : '053816200',
    'dob' : '01311997'
}
print(patient_3)
# Out:
# {'name': 'Jack', 'last_name': 'Jillianson', 'mrn': '053816200', 'dob': '01311997'}

# %%
#excercises on dictionaries
#Use a dictionary to store information about someone you know.
#First namelast name, age, city, and one other piece of information. Print each piece ofinformation out.
person_iknow = {
    'name' : 'Guy',
    'last name' : 'fieri',
    'age' : '57',
    'city': 'Memphis',
    'job' : 'foodie'
}
print(person_iknow)
# Out:
# {'name': 'Guy', 'last name': 'fieri', 'age': '57', 'city': 'Memphis', 'job': 'foodie'}

# %%
#Use a dictionary to store 5 people you know and their ages. Print eachpersons name and age.
another_person = {
    'name': ['guy','john','jack','elvis','harry'],
    'age': ['57','54','28','89','32']
}
#or-- doesnt run
#another_per = [{'name': 'guy', 'age':'57'},{'name': 'john', 'age':'54'},{'name': 'jack', 'age':'28'},
 #{'name': 'elvis', 'age':'89'}, {'name': 'harry', 'age':'32'}]
#print(another_per['name'], another_per['age'])
# Out:
#   File "/tmp/ipython-input-2349902669.py", line 9
#     print(f{another_per['name'], another_per['age']})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Create a dictionary storing vocab words we’ve spoken about – store at least 3.
#Think of making a “glossary”. Print each word and its definition, separatedby a colon (:).
#Make the output clean and easy to read.
glossary = {
    'dictionary' : 'ordered and unchangeable, no duplicates',
    'set' : 'ordered and unchanaged, can remove and add, unidexed, no duplicates',
    'tuple' : 'ordered and unchanagavle, allows duplicates'
}
print(glossary)
# Out:
# {'dictionary': 'ordered and unchangeable, no duplicates', 'set': 'ordered and unchanaged, can remove and add, unidexed, no duplicates', 'tuple': 'ordered and unchanagavle, allows duplicates'}

# %%
#while loops
#ex 1 (1 gets reassigned until condition, so second num word is now = to 6)
number = 1
while number <= 5:
    print(number)
    number += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#while loops and user input
prompt = 'input message. I will repeat until you type quit'
message = ''

while message != 'quit':
    message = input(prompt)
    print(message)
# Out:
# input message. I will repeat until you type quitquit
# quit

# %%
#done
