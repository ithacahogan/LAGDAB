# %% [markdown]
# <a href="https://colab.research.google.com/github/ithacahogan/LAGDAB/blob/main/20250905.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#start of friday lecture
#defining functions
def age (yearsoflife):
  print("I am " + yearsoflife + "y.o. today!")
age('52')
# Out:
# I am 52y.o. today!

# %%
#MODIFYING age
def age (first, last, age=15):
  print("My name is " + first + last + 'and '+ 'I am ' + str(age) + "y.o. today!")

age (first= 'Paul ', last= 'Goatee ', age=52)
# Out:
# My name is Paul Goatee and I am 52y.o. today!

# %%
#Breakout Time
#Write a function that accepts two arguments, for example city and country, hospital name and department, etc.​
#Call your function 3 times – for three different examples – i.e. New York, New jersey, Florida​
#Modify your function to take in a default parameter. (The default is in the def function with the =)

def location(city = 'Burlington', airportcode = 'BTV'):
  print('If you want to fly to: ' + city + ', research flights into: ' + airportcode)

location('New York', 'JFK'),
location('Washington, D.C.', 'DCA'),
location('Seattle', 'SEA'),
location('Calgary', 'YYC'),
location('Cancun','CUN'),
location()
# Out:
# If you want to fly to: New York, research flights into: JFK
# If you want to fly to: Washington, D.C., research flights into: DCA
# If you want to fly to: Seattle, research flights into: SEA
# If you want to fly to: Calgary, research flights into: YYC
# If you want to fly to: Cancun, research flights into: CUN
# If you want to fly to: Burlington, research flights into: BTV
