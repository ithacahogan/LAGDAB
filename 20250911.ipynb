# %% [markdown]
# <a href="https://colab.research.google.com/github/ithacahogan/LAGDAB/blob/main/20250911.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#September 11, 2025
#Python for Data Analytics- Visualization
import pandas as pd
import numpy as np

#first part of chaining and cleaning..
url = 'https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv'
date_cols = ['created data', 'closed date', 'resolution action updateddate'] #global variable that calls 2 columns
df = pd.read_csv(
    url,
    low_memory = False,
    dtype = {"incident zip":"string","zip":"string","vehicle type":"string"},
    parse_dates=[c for c in date_cols if c in pd.read_csv(url, nrows=0).columns]
    )
df.head(3)
#url, is showing source of data. low_mem- shows most mem avail, parses faster
#dtype (datatype) validating the dtype of the columns we care about in the subset
#pd.read_csv(..).columns is to check whether columns names are correct, so just seeing header
#now learning how to unzip a file in pandas, rather than unzip it before
# Out:
#    Unique Key   Created Date      Closed Date Agency  Complaint Type  \
# 0    42680103  5/1/2019 0:00  5/16/2019 21:45    DEP    Water System
# 1    42530481  5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# 2    42527619  5/1/2019 0:00   5/13/2019 0:00  DOHMH  Food Poisoning
#
#                 Location Type Incident Zip      Incident Address  \
# 0                         NaN        11420     127-16 111 AVENUE
# 1  Restaurant/Bar/Deli/Bakery        10011  207 WEST   14 STREET
# 2  Restaurant/Bar/Deli/Bakery        10025         2664 BROADWAY
#
#         Street Name Address Type  ... Landmark Facility Type  Status  \
# 0        111 AVENUE      ADDRESS  ...      NaN           NaN  Closed
# 1  WEST   14 STREET      ADDRESS  ...      NaN           NaN  Closed
# 2          BROADWAY      ADDRESS  ...      NaN           NaN  Closed
#
#           Due Date                             Resolution Description  \
# 0              NaN  The Department of Environment Protection inspe...
# ...
